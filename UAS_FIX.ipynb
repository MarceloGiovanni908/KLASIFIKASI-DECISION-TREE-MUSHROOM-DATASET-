# %%
import pandas as pd

# %%
#load dataset
dataset = pd.read_csv("mushroom_dataset_new.csv")

# %%
dataset
# Out:
#      cap-shape cap-surface cap-color  bruises    odor gill-attachment  \
# 0       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 1       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 2       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 3       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 4       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# ...        ...         ...       ...      ...     ...             ...
# 8411   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
# 8412   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
# 8413   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
# 8414   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
# 8415   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0         CROWDED    NARROW      WHITE    TAPERING  ...
# ...

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [cap-shape, cap-surface, cap-color, bruises, odor, gill-attachment, gill-spacing, gill-size, gill-color, stalk-shape, stalk-root, stalk-surface-above-ring, stalk-surface-below-ring, stalk-color-above-ring, stalk-color-below-ring, veil-color, ring-number, ring-type, spore-print-color, population, habitat, mushroom]
# Index: []
#
# [0 rows x 22 columns]

# %%
#mengganti missing value pada kolom stalk-root dengan modusnya
mode = dataset[dataset["stalk-root"]!="?"]["stalk-root"].mode()[0]
dataset['stalk-root'] = dataset['stalk-root'].replace("?", mode)

# %%
dataset
# Out:
#      cap-shape cap-surface cap-color  bruises    odor gill-attachment  \
# 0       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 1       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 2       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 3       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 4       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# ...        ...         ...       ...      ...     ...             ...
# 8411   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
# 8412   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
# 8413   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
# 8414   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
# 8415   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0         CROWDED    NARROW      WHITE    TAPERING  ...
# ...

# %%
dataset['stalk-root']
# Out:
# 0       BULBOUS
# 1       BULBOUS
# 2       BULBOUS
# 3       BULBOUS
# 4       BULBOUS
#          ...
# 8411    BULBOUS
# 8412    BULBOUS
# 8413    BULBOUS
# 8414    BULBOUS
# 8415    BULBOUS
# Name: stalk-root, Length: 8416, dtype: object

# %%
#mengubah data kategorikal menjadi numerikal untuk melakukan proses learning
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
dataset['cap-shape']=le.fit_transform(dataset['cap-shape'])
dataset['cap-surface']=le.fit_transform(dataset['cap-surface'])
dataset['cap-color']=le.fit_transform(dataset['cap-color'])
dataset['bruises']=le.fit_transform(dataset['bruises'])
dataset['odor']=le.fit_transform(dataset['odor'])
dataset['gill-attachment']=le.fit_transform(dataset['gill-attachment'])
dataset['gill-spacing']=le.fit_transform(dataset['gill-spacing'])
dataset['gill-size']=le.fit_transform(dataset['gill-size'])
dataset['gill-color']=le.fit_transform(dataset['gill-color'])
dataset['stalk-shape']=le.fit_transform(dataset['stalk-shape'])
dataset['stalk-root']=le.fit_transform(dataset['stalk-root'])
dataset['stalk-surface-above-ring']=le.fit_transform(dataset['stalk-surface-above-ring'])
dataset['stalk-surface-below-ring']=le.fit_transform(dataset['stalk-surface-below-ring'])
dataset['stalk-color-above-ring']=le.fit_transform(dataset['stalk-color-above-ring'])
dataset['stalk-color-below-ring']=le.fit_transform(dataset['stalk-color-below-ring'])
dataset['veil-color']=le.fit_transform(dataset['veil-color'])
dataset['ring-number']=le.fit_transform(dataset['ring-number'])
dataset['ring-type']=le.fit_transform(dataset['ring-type'])
dataset['spore-print-color']=le.fit_transform(dataset['spore-print-color'])
dataset['population']=le.fit_transform(dataset['population'])
dataset['habitat']=le.fit_transform(dataset['habitat'])

# %%
dataset
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             2            3          8        0     0                1
# 1             2            3          8        0     0                1
# 2             2            3          8        0     0                1
# 3             2            3          8        0     0                1
# 4             2            3          8        0     0                1
# ...         ...          ...        ...      ...   ...              ...
# 8411          4            3          0        1     6                0
# 8412          4            3          0        1     6                0
# 8413          4            3          0        1     6                0
# 8414          4            3          0        1     6                0
# 8415          4            3          0        1     6                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
#memisahkan fitur dan kelas
fitur = ['cap-shape','cap-surface','cap-color','bruises','odor','gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape','stalk-root','stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring','stalk-color-below-ring','veil-color','ring-number','ring-type','spore-print-color','population','habitat'] 
X = dataset[fitur] 
y = dataset['mushroom']

# %%
X
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             2            3          8        0     0                1
# 1             2            3          8        0     0                1
# 2             2            3          8        0     0                1
# 3             2            3          8        0     0                1
# 4             2            3          8        0     0                1
# ...         ...          ...        ...      ...   ...              ...
# 8411          4            3          0        1     6                0
# 8412          4            3          0        1     6                0
# 8413          4            3          0        1     6                0
# 8414          4            3          0        1     6                0
# 8415          4            3          0        1     6                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
y
# Out:
# 0       EDIBLE
# 1       EDIBLE
# 2       EDIBLE
# 3       EDIBLE
# 4       EDIBLE
#          ...
# 8411    EDIBLE
# 8412    EDIBLE
# 8413    EDIBLE
# 8414    EDIBLE
# 8415    EDIBLE
# Name: mushroom, Length: 8416, dtype: object

# %%
#membagi data training(80%) dan data testing(20%)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
X_train
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 5371          3            2          9        1     4                1
# 2930          2            2          0        0     6                1
# 7051          3            2          7        1     3                1
# 6382          2            3          0        1     8                1
# 3449          3            0          0        0     6                1
# ...         ...          ...        ...      ...   ...              ...
# 4373          2            0          9        1     4                1
# 7891          0            3          8        1     6                1
# 4859          3            0          3        1     4                1
# 3264          3            0          7        0     6                1
# 2732          2            2          3        0     6                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
X_test
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 6637          2            2          0        1     8                1
# 2407          2            0          7        0     6                1
# 4858          3            0          3        1     4                1
# 2171          3            0          0        1     6                1
# 2563          2            0          0        0     6                1
# ...         ...          ...        ...      ...   ...              ...
# 2475          2            0          0        0     6                1
# 4237          2            0          3        1     4                1
# 3116          3            0          3        0     6                1
# 7678          4            2          7        1     8                1
# 2883          2            2          7        0     6                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
y_train
# Out:
# 5371    POISONOUS
# 2930       EDIBLE
# 7051    POISONOUS
# 6382    POISONOUS
# 3449       EDIBLE
#           ...
# 4373    POISONOUS
# 7891       EDIBLE
# 4859    POISONOUS
# 3264       EDIBLE
# 2732       EDIBLE
# Name: mushroom, Length: 6732, dtype: object

# %%
y_test
# Out:
# 6637    POISONOUS
# 2407       EDIBLE
# 4858    POISONOUS
# 2171       EDIBLE
# 2563       EDIBLE
#           ...
# 2475       EDIBLE
# 4237    POISONOUS
# 3116       EDIBLE
# 7678    POISONOUS
# 2883       EDIBLE
# Name: mushroom, Length: 1684, dtype: object

# %%
#membuat model tree dari data training
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()

# %%
from sklearn import tree
from sklearn.tree import export_text
tree.plot_tree(clf.fit(X_train,y_train))
model = export_text(clf, feature_names = fitur)
print(model)
# Out:
# |--- spore-print-color <= 2.50
# |   |--- gill-size <= 0.50
# |   |   |--- class: EDIBLE
# |   |--- gill-size >  0.50
# |   |   |--- cap-surface <= 1.00
# |   |   |   |--- habitat <= 5.00
# |   |   |   |   |--- class: EDIBLE
# |   |   |   |--- habitat >  5.00
# |   |   |   |   |--- bruises <= 0.50
# |   |   |   |   |   |--- class: EDIBLE
# |   |   |   |   |--- bruises >  0.50
# |   |   |   |   |   |--- class: POISONOUS
# |   |   |--- cap-surface >  1.00
# |   |   |   |--- odor <= 1.50
# |   |   |   |   |--- class: EDIBLE
# |   |   |   |--- odor >  1.50
# |   |   |   |   |--- class: POISONOUS
# |--- spore-print-color >  2.50
# |   |--- ring-number <= 1.50
# |   |   |--- veil-color <= 1.50
# |   |   |   |--- class: EDIBLE
# |   |   |--- veil-color >  1.50
# |   |   |   |--- gill-spacing <= 0.50
# |   |   |   |   |--- stalk-surface-below-ring <= 0.50
# |   |   |   |   |   |--- cap-surface <= 2.50
# |   |   |   |   |   |   |--- class: EDIBLE
# ...

# %%
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image
import pydotplus

# %%
#melihat model tree menggunakan gambar
dot_data = StringIO()
export_graphviz(clf,out_file=dot_data,filled=True,rounded=True,special_characters=True,feature_names=fitur,class_names=['EDIBLE','POISONOUS'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('mushroom.png')
Image(graph.create_png())

# %%
#memprediksi isi label mushroom dari data test
y_prediksi=clf.predict(X_test)

# %%
y_prediksi
# Out:
# array(['POISONOUS', 'EDIBLE', 'POISONOUS', ..., 'EDIBLE', 'POISONOUS',
#        'EDIBLE'], dtype=object)

# %%
#menampilkan data isi label mushroom yang sebenarnya
y_test
# Out:
# 6637    POISONOUS
# 2407       EDIBLE
# 4858    POISONOUS
# 2171       EDIBLE
# 2563       EDIBLE
#           ...
# 2475       EDIBLE
# 4237    POISONOUS
# 3116       EDIBLE
# 7678    POISONOUS
# 2883       EDIBLE
# Name: mushroom, Length: 1684, dtype: object

# %%
#membuat confusion matriks
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_prediksi)

# %%
cm
#dari confusion matriks dibawah dapat disimpulkan bahwa model kita sangat baik karena prediksi salahnya sebesar 0. Artinya
#memiliki 100% akurasi
# Out:
# array([[898,   0],
#        [  0, 786]], dtype=int64)

# %%
#menampilkan akurasi
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

print(classification_report(y_test,y_prediksi))
akurasi = accuracy_score(y_test,y_prediksi)
print("Akurasi : ", akurasi)
# Out:
#               precision    recall  f1-score   support
#
#       EDIBLE       1.00      1.00      1.00       898
#    POISONOUS       1.00      1.00      1.00       786
#
#     accuracy                           1.00      1684
#    macro avg       1.00      1.00      1.00      1684
# weighted avg       1.00      1.00      1.00      1684
#
# Akurasi :  1.0
